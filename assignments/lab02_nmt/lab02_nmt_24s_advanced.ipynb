# %% [markdown]
# ## Lab assignment 02

# %% [markdown]
# ### Neural Machine Translation in the wild
# In the third homework you are supposed to get the best translation you can for the RU-EN translation task.
#
# Basic approach using RNNs as encoder and decoder is implemented for you.
#
# Your ultimate task is to use the techniques we've covered, e.g.
#
# * Optimization enhancements (e.g. learning rate decay)
#
# * Transformer/CNN/<whatever you select> encoder (with or without positional encoding)
#
# * attention/self-attention mechanism (**highly recommended**)
#
# * custom tokenization (BPE units, other subword approaches)
#
# to improve the translation quality.
#
# --------
#
# * __Please use at least three different approaches/models and compare them (translation quality/complexity/training and evaluation time).__
#
# * Write down some summary on your experiments and illustrate it with convergence plots/metrics and your thoughts. Just like you would approach a real problem.

# %%
# You might need to install the libraries below. Do it in the desired environment
# if you are working locally.

! pip  install subword-nmt
! pip install nltk
! pip install torchtext
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: subword-nmt in /home/stanislav/.local/lib/python3.10/site-packages (0.3.8)
# Requirement already satisfied: tqdm in /home/stanislav/.local/lib/python3.10/site-packages (from subword-nmt) (4.66.2)
# Requirement already satisfied: mock in /home/stanislav/.local/lib/python3.10/site-packages (from subword-nmt) (5.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/stanislav/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: joblib in /home/stanislav/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in /home/stanislav/.local/lib/python3.10/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/stanislav/.local/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchtext in /home/stanislav/.local/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: tqdm in /home/stanislav/.local/lib/python3.10/site-packages (from torchtext) (4.66.2)
# Requirement already satisfied: requests in /home/stanislav/.local/lib/python3.10/site-packages (from torchtext) (2.31.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from torchtext) (1.16.0)
# Requirement already satisfied: torch in /home/stanislav/.local/lib/python3.10/site-packages (from torchtext) (2.2.1)
# Requirement already satisfied: numpy in /home/stanislav/.local/lib/python3.10/site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: sentencepiece in /home/stanislav/.local/lib/python3.10/site-packages (from torchtext) (0.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/stanislav/.local/lib/python3.10/site-packages (from requests->torchtext) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/stanislav/.local/lib/python3.10/site-packages (from requests->torchtext) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/stanislav/.local/lib/python3.10/site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/stanislav/.local/lib/python3.10/site-packages (from requests->torchtext) (2023.11.17)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (2.19.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.3.1)
# Requirement already satisfied: sympy in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (11.4.5.107)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (8.9.2.26)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.105)
# Requirement already satisfied: filelock in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (3.13.1)
# Requirement already satisfied: networkx in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (3.2.1)
# Requirement already satisfied: jinja2 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (3.1.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.0.106)
# Requirement already satisfied: triton==2.2.0 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (2.2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (4.10.0)
# Requirement already satisfied: fsspec in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/stanislav/.local/lib/python3.10/site-packages (from torch->torchtext) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/stanislav/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->torchtext) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/stanislav/.local/lib/python3.10/site-packages (from jinja2->torch->torchtext) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/stanislav/.local/lib/python3.10/site-packages (from sympy->torch->torchtext) (1.3.0)

# %%
# Thanks to YSDA NLP course team for the data
# (who thanks tilda and deephack teams for the data in their turn)

import os
path_do_data = '../../datasets/Machine_translation_EN_RU/data.txt'
if not os.path.exists(path_do_data):
    print("Dataset not found locally. Downloading from github.")
    # !wget https://raw.githubusercontent.com/neychev/made_nlp_course/master/datasets/Machine_translation_EN_RU/data.txt -nc
    path_do_data = './data.txt'
# Out:
# Dataset not found locally. Downloading from github.
# File 'data.txt' already there; not retrieving.

# %% [markdown]
# #### Grading criteria
#
# **100%**
# - implementation of at least 3 model improvements over baseline
# - threshold of 27 BLEU on test corpus
# - experimental results and conclusions in human-readable format :)
#
# **70%**
# - implementation of at least 2 model improvements over baseline
# - threshold of 25 BLEU on test corpus
# - experimental results and conclusions in human-readable format :)
#
# **30%**
# - implementation of at least 1 model improvement over baseline
# - threshold of 21 BLEU on test corpus
# - experimental results and conclusions in human-readable format :)
#
#
# ------
#
# #### **Note: Please do not use pretrained machine translation / BERT / LLM checkpoints. All such solutions will be graded at 30% pts.**

# %% [markdown]
# ### Warning! The code below is deeeeeeeply deprecated and is is provided only as simple guide.
# We suggest you to stick to most recent pipelines here, e.g. by Huggingface:
# * Example notebook: [link](https://github.com/huggingface/notebooks/blob/main/examples/translation.ipynb)
# * Converting your own dataset to specific format: [link](https://discuss.huggingface.co/t/correct-way-to-create-a-dataset-from-a-csv-file/15686/15)

# %%
# old deprecated code
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import TranslationDataset, Multi30k
from torchtext.data import Field, BucketIterator

import spacy

import random
import math
import time

import matplotlib
matplotlib.rcParams.update({'figure.figsize': (16, 12), 'font.size': 14})
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output

from nltk.tokenize import WordPunctTokenizer
from subword_nmt.learn_bpe import learn_bpe
from subword_nmt.apply_bpe import BPE

# %% [markdown]
# ### Main part
# __Here comes the preprocessing. Do not hesitate to use BPE or more complex preprocessing ;)__

# %%
tokenizer_W = WordPunctTokenizer()
def tokenize(x, tokenizer=tokenizer_W):
    return tokenizer.tokenize(x.lower())

# %%
SRC = Field(tokenize=tokenize,
            init_token = '<sos>',
            eos_token = '<eos>',
            lower = True)

TRG = Field(tokenize=tokenize,
            init_token = '<sos>',
            eos_token = '<eos>',
            lower = True)

dataset = torchtext.data.TabularDataset(
    path=path_do_data,
    format='tsv',
    fields=[('trg', TRG), ('src', SRC)]
)

# %%
train_data, valid_data, test_data = dataset.split(split_ratio=[0.8, 0.15, 0.05])

# %%
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 40000
# Number of validation examples: 2500
# Number of testing examples: 7500

# %%
SRC.build_vocab(train_data, min_freq = 3)
TRG.build_vocab(train_data, min_freq = 3)

# %%
print(f"Unique tokens in source (ru) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (en) vocabulary: {len(TRG.vocab)}")
# Out:
# Unique tokens in source (ru) vocabulary: 9284
# Unique tokens in target (en) vocabulary: 6718

# %% [markdown]
# Here are tokens from original (RU) corpus:

# %%
SRC.vocab.itos[::1000]
# Out:
# ['<unk>',
#  'прогулку',
#  'point',
#  'книг',
#  'antica',
#  'фасадом',
#  'margarita',
#  'таормина',
#  'декорированные',
#  'стереосистемой']

# %% [markdown]
# And from target (EN) corpus:

# %%
TRG.vocab.itos[::1000]
# Out:
# ['<unk>', 'speed', 'classical', 'belvedere', 'morro', 'salami', 'magazine']

# %% [markdown]
# And here is example from train dataset:

# %%
print(vars(train_data.examples[9]))
# Out:
# {'trg': ['if', 'you', 'feel', 'like', 'visiting', 'the', 'surroundings', ',', 'check', 'out', 'discovery', 'chair', '(', '11', ')', '(', '200', 'metres', ')', 'and', 'broadway', 'express', '(', '1', ')', '(', '300', 'metres', ').'], 'src': ['в', '200', 'метрах', 'находится', 'станция', 'лыжного', 'подъемника', '«', 'дискавери', 'чэир', '»', '(', '11', '),', 'а', 'в', '300', 'метрах', '—', 'станция', '«', 'бродвей', 'экспресс', '»', '(', '1', ').']}

# %% [markdown]
# Let's check the length distributions:

# %%
src_length = map(len, [vars(x)['src'] for x in train_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in train_data.examples])

print('Length distribution in Train data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Train data

# %%
src_length = map(len, [vars(x)['src'] for x in test_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in test_data.examples])

print('Length distribution in Test data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Test data

# %% [markdown]
# ### Model side
# __Here comes simple pipeline of NMT model learning. It almost copies the week02 practice__

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
def _len_sort_key(x):
    return len(x.src)

BATCH_SIZE = 128

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size = BATCH_SIZE,
    device = device,
    sort_key=_len_sort_key
)

# %%
for x in train_iterator:
    break
print(x)
print(x.src.shape, x.trg.shape)
# Out:
# [torchtext.data.batch.Batch of size 128]
# 	[.trg]:[torch.cuda.LongTensor of size 42x128 (GPU 0)]
# 	[.src]:[torch.cuda.LongTensor of size 45x128 (GPU 0)]
# torch.Size([45, 128]) torch.Size([42, 128])

# %%
import my_network
Encoder = my_network.Encoder
Decoder = my_network.Decoder
Seq2Seq = my_network.Seq2Seq

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

# dont forget to put the model to the right device
model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    # <YOUR CODE HERE>
    for name, param in m.named_parameters():
        nn.init.uniform_(param, -0.08, 0.08)

model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(9284, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(6718, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (out): Linear(in_features=512, out_features=6718, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 14,899,262 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['<pad>']
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip, train_history=None, valid_history=None):
    model.train()

    epoch_loss = 0
    history = []
    for i, batch in enumerate(iterator):

        src = batch.src
        trg = batch.trg

        optimizer.zero_grad()

        output = model(src, trg)

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)

        #trg = [(trg sent len - 1) * batch size]
        #output = [(trg sent len - 1) * batch size, output dim]

        loss = criterion(output, trg)

        loss.backward()

        # Let's clip the gradient
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)

        optimizer.step()

        epoch_loss += loss.item()

        history.append(loss.cpu().data.numpy())
        if (i+1)%10==0:
            fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

            clear_output(True)
            ax[0].plot(history, label='train loss')
            ax[0].set_xlabel('Batch')
            ax[0].set_title('Train loss')
            if train_history is not None:
                ax[1].plot(train_history, label='general train history')
                ax[1].set_xlabel('Epoch')
            if valid_history is not None:
                ax[1].plot(valid_history, label='general valid history')
            plt.legend()

            plt.show()


    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):

    model.eval()

    epoch_loss = 0

    history = []

    with torch.no_grad():

        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg sent len, batch size]
            #output = [trg sent len, batch size, output dim]

            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)

            #trg = [(trg sent len - 1) * batch size]
            #output = [(trg sent len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()

    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
train_history = []
valid_history = []

N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):

    start_time = time.time()

    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut1-model.pt')

    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')

# %% [markdown]
# __Let's take a look at our network quality__:

# %%
# del utils

# %%
import utils
import imp
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten
# Out:
# /tmp/ipykernel_2874/3680124227.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model, TRG.vocab)
# Out:
# Original: there is a 24 - hour front desk at the property .
# Generated: there is a 24 - hour front desk .
#
# Original: the complex also has a handy on - site supermarket .
# Generated: a a - minute walk .

# %%
from nltk.translate.bleu_score import corpus_bleu

#     """ Estimates corpora-level BLEU score of model's translations given inp and reference out """
#     translations, _ = model.translate_lines(inp_lines, **flags)
#     # Note: if you experience out-of-memory error, split input lines into batches and translate separately
#     return corpus_bleu([[ref] for ref in out_lines], translations) * 100

# %%
import tqdm

# %%
original_text = []
generated_text = []
model.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)

        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])

# original_text = flatten(original_text)
# generated_text = flatten(generated_text)
# Out:
# 0it [00:00, ?it/s]
# 59it [00:05, 11.26it/s]

# %%
seq2seq_bleu = corpus_bleu([[text] for text in original_text], generated_text) * 100
print(seq2seq_bleu)
# Out:
# 28.15490046928225

# %% [markdown]
# # Attention mechanism

# %%
import attention_mechanism
AttentionEncoder = attention_mechanism.Encoder
AttentionDecoder = attention_mechanism.Decoder
AttentionSeq2Seq = attention_mechanism.Seq2Seq

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = AttentionEncoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = AttentionDecoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

# dont forget to put the model to the right device
model = AttentionSeq2Seq(enc, dec, device).to(device)

# %%
model.apply(init_weights)
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 17,004,360 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['']
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %%
train_history = []
valid_history = []

N_EPOCHS = 10
CLIP = 5

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):

    start_time = time.time()

    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut2-model.pt')

    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 10 | Time: 2m 23s
# 	Train Loss: 1.115 | Train PPL:   3.048
# 	 Val. Loss: 3.668 |  Val. PPL:  39.183

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model, TRG.vocab)
# Out:
# Original: there is a 24 - hour front desk at the property .
# Generated: kettle desk is a a a a a a a a a a a
#
# Original: the complex also has a handy on - site supermarket .
# Generated: is a a a .

# %%
original_text = []
generated_text = []
model.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)
        
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])
# Out:
# 59it [00:05, 10.11it/s]

# %%
seq2seq_attention_bleu = corpus_bleu([[text] for text in original_text], generated_text) * 100
print(seq2seq_attention_bleu)
# Out:
# 16.099354000555635

# %% [markdown]
# # BPE

# %%
import sentencepiece as spm
import pandas as pd

data = pd.read_csv(path_do_data, sep = "\t", header = None).sample(frac = .8)
data[0].to_csv("eng.txt", sep = '\t', header = False, index = False)
data[1].to_csv("ru.txt", sep = '\t', header = False, index = False)

spm.SentencePieceTrainer.train(input = 'ru.txt', model_prefix = 'm_ru', vocab_size = 2500, model_type = 'bpe')
spm.SentencePieceTrainer.train(input = 'eng.txt', model_prefix = 'm_eng', vocab_size = 2500, model_type = 'bpe')
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ru.txt
#   input_format:
#   model_prefix: m_ru
#   model_type: BPE
#   vocab_size: 2500
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: ru.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 40000 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=3870557
# trainer_interface.cc(550) LOG(INFO) Done: 99.9535% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=134
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999535
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 40000 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 40000
# trainer_interface.cc(609) LOG(INFO) Done! 50321
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57160 min_freq=98
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20015 size=20 all=4172 active=1897 piece=ет
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12187 size=40 all=5297 active=3022 piece=ей
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8649 size=60 all=6617 active=4342 piece=ост
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6606 size=80 all=7606 active=5331 piece=ии
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5303 size=100 all=8754 active=6479 piece=▁наход
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5296 min_freq=398
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4626 size=120 all=9297 active=1540 piece=же
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4092 size=140 all=9960 active=2203 piece=▁пре
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3648 size=160 all=10680 active=2923 piece=▁Wi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3263 size=180 all=11492 active=3735 piece=▁пл
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2923 size=200 all=12213 active=4456 piece=▁х
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2921 min_freq=360
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2672 size=220 all=12780 active=1551 piece=ов
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2445 size=240 all=13491 active=2262 piece=▁могут
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2307 size=260 all=13965 active=2736 piece=стояние
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2140 size=280 all=14490 active=3261 piece=▁Расстояние
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1994 size=300 all=15026 active=3797 piece=▁принадлеж
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1985 min_freq=311
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1823 size=320 all=15615 active=1586 piece=▁комната
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1736 size=340 all=15917 active=1888 piece=▁под
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1625 size=360 all=16326 active=2297 piece=▁ав
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1519 size=380 all=17054 active=3025 piece=бель
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1394 size=400 all=17672 active=3643 piece=▁Апартаменты
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1389 min_freq=277
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1322 size=420 all=18058 active=1387 piece=▁блюда
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1260 size=440 all=18554 active=1883 piece=or
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1152 size=460 all=18945 active=2274 piece=ное
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1084 size=480 all=19377 active=2706 piece=▁ж
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1041 size=500
#  all=19865 active=3194 piece=▁оформлен
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1039 min_freq=237
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=996 size=520 all=20227 active=1351 piece=им
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=959 size=540 all=20528 active=1652 piece=уточ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=921 size=560 all=20744 active=1868 piece=▁дом
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=879 size=580 all=20953 active=2077 piece=зала
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=848 size=600 all=21376 active=2500 piece=▁Та
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=847 min_freq=200
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=804 size=620 all=21749 active=1406 piece=ве
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=775 size=640 all=22200 active=1857 piece=сс
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=726 size=660 all=22583 active=2240 piece=▁занима
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=693 size=680 all=22903 active=2560 piece=▁занимает
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=646 size=700 all=23227 active=2884 piece=ян
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=646 min_freq=167
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=616 size=720 all=23810 active=1673 piece=ассаж
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=584 size=740 all=23970 active=1833 piece=тив
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=564 size=760 all=24307 active=2170 piece=▁заказать
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=530 size=780 all=24875 active=2738 piece=om
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=509 size=800 all=25426 active=3289 piece=▁ва
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=509 min_freq=139
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=496 size=820 all=25662 active=1497 piece=▁типа
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=481 size=840 all=26156 active=1991 piece=енца
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=468 size=860 all=26516 active=2351 piece=▁пров
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=455 size=880 all=26880 active=2715 piece=нии
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=445 size=900 all=27056 active=2891 piece=et
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=443 min_freq=121
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=435 size=920 all=27380 active=1576 piece=▁гостиной
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=424 size=940 all=27511 active=1707 piece=▁пользоваться
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=405 size=960 all=27735 active=1931 piece=ок
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=389 size=980 all=28039 active=2235 piece=▁велосипед
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=381 size=1000 all=28662 active=2858 piece=▁приготов
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=380 min_freq=106
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=369 size=1020 all=28940 active=1707 piece=▁мебель
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=351 size=1040 all=29202 active=1969 piece=▁станции
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=339 size=1060 all=29439 active=2206 piece=▁25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=329 size=1080 all=29681 active=2448 piece=▁круглосуточная
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=322 size=1100 all=29967 active=2734 piece=▁уголок
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=321 min_freq=95
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=312 size=1120 all=30249 active=1781 piece=od
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=306 size=1140 all=30691 active=2223 piece=ing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=298 size=1160 all=31010 active=2542 piece=▁Е
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=291 size=1180 all=31244 active=2776 piece=▁прачечной
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=281 size=1200 all=31515 active=3047 piece=чески
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=280 min_freq=83
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=272 size=1220 all=31879 active=1924 piece=▁машина
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=264 size=1240 all=32201 active=2246 piece=▁заку
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=258 size=1260 all=32381 active=2426 piece=▁Каждое
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=252 size=1280 all=32602 active=2647 piece=йской
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=246 size=1300 all=32821 active=2866 piece=льные
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=246 min_freq=75
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=239 size=1320 all=33189 active=1998 piece=▁велосипедов
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=232 size=1340 all=33444 active=2253 piece=ге
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=227 size=1360 all=33987 active=2796 piece=▁бы
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=221 size=1380 all=34235 active=3044 piece=▁би
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=215 size=1400 all=34436 active=3245 piece=▁меблирован
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=215 min_freq=68
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=209 size=1420 all=34735 active=2011 piece=▁ресторана
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=1440 all=35007 active=2283 piece=▁музея
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=199 size=1460 all=35136 active=2412 piece=кие
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=194 size=1480 all=35317 active=2593 piece=мотр
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=190 size=1500 all=35527 active=2803 piece=еть
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=190 min_freq=62
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=184 size=1520 all=35775 active=2014 piece=ющий
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=182 size=1540 all=35982 active=2221 piece=▁турист
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=178 size=1560 all=36216 active=2455 piece=табель
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=175 size=1580 all=36456 active=2695 piece=▁которых
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=172 size=1600 all=36665 active=2904 piece=▁поиграть
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=171 min_freq=57
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=169 size=1620 all=36820 active=1989 piece=▁ванные
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=166 size=1640 all=37141 active=2310 piece=▁месте
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=163 size=1660 all=37419 active=2588 piece=��ческом
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=160 size=1680 all=37630 active=2799 piece=ul
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=157 size=1700 all=38055 active=3224 piece=▁Рядом
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=157 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=155 size=1720 all=38360 active=2208 piece=эропорт
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=1740 all=38675 active=2523 piece=▁зонах
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=1760 all=38876 active=2724 piece=доров
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=1780 all=39027 active=2875 piece=тальян
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=1800 all=39298 active=3146 piece=▁вин
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=142 min_freq=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=1820 all=39410 active=2066 piece=▁множе��тво
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=1840 all=39825 active=2481 piece=▁загара
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=1860 all=39987 active=2643 piece=▁Pal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=1880 all=40307 active=2963 piece=телеви
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=1900 all=40545 active=3201 piece=зле
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=130 min_freq=45
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=1920 all=40664 active=2143 piece=▁прямо
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=1940 all=40935 active=2414 piece=▁ск
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=124 size=1960 all=41209 active=2688 piece=ользу
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=1980 all=41547 active=3026 piece=ыск
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=2000 all=41660 active=3139 piece=▁современные
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=120 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=2020 all=41853 active=2276 piece=▁гладильные
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=2040 all=42099 active=2522 piece=▁входит
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=2060 all=42243 active=2666 piece=ческого
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=2080 all=42462 active=2885 piece=ился
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=2100 all=42590 active=3013 piece=ву
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=110 min_freq=40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=2120 all=42787 active=2300 piece=довать
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=2140 all=42991 active=2504 piece=▁сно
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=106 size=2160 all=43182 active=2695 piece=▁останавли
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=2180 all=43355 active=2868 piece=▁Ви
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=2200 all=43596 active=3109 piece=▁Сов
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=103 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=2220 all=43787 active=2365 piece=дки
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=2240 all=43945 active=2523 piece=▁более
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=2260 all=44095 active=2673 piece=звездочный
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=2280 all=44360 active=2938 piece=▁лобби
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=2300 all=44367 active=2945 piece=▁двуспаль
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=95 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=2320 all=44568 active=2414 piece=▁собственным
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=2340 all=44891 active=2737 piece=сел
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=2360 all=45032 active=2878 piece=▁водой
# trainer_interface.cc(687) LOG(INFO) Saving model: m_ru.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m_ru.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: eng.txt
#   input_format:
#   model_prefix: m_eng
#   model_type: BPE
#   vocab_size: 2500
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: eng.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 40000 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=3425116
# trainer_interface.cc(550) LOG(INFO) Done: 99.9516% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=84
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999516
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 40000 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 40000
# trainer_interface.cc(609) LOG(INFO) Done! 38213
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=97682 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20443 size=20 all=3209 active=1947 piece=▁is
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12132 size=40 all=4466 active=3204 piece=▁d
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8636 size=60 all=5501 active=4239 piece=ay
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5693 size=80 all=6646 active=5384 piece=▁room
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4960 size=100 all=7498 active=6236 piece=able
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4927 min_freq=224
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4503 size=120 all=8422 active=1895 piece=ls
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3721 size=140 all=9190 active=2663 piece=port
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3298 size=160 all=9817 active=3290 piece=▁includ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2878 size=180 all=10245 active=3718 piece=erv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2602 size=200 all=11101 active=4574 piece=▁restauran
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2594 min_freq=217
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2295 size=220 all=11752 active=1650 piece=▁parking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2068 size=240 all=12132 active=2030 piece=oy
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1870 size=260 all=12906 active=2804 piece=ce
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1742 size=280 all=13304 active=3202 piece=reakfast
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1611 size=300 all=14033 active=3931 piece=round
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1606 min_freq=193
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1456 size=320 all=14280 active=1237 piece=ul
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1302 size=340 all=14901 active=1858 piece=▁Station
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1128 size=360 all=15371 active=2328 piece=onditioned
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1050 size=380 all=15854 active=2811 piece=out
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=976 size=400 all=16198 active=3155 piece=▁toilet
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=973 min_freq=166
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=928 size=420 all=16523 active=1321 piece=atellite
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=871 size=440 all=16841 active=1639 piece=ass
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=816 size=460 all=17661 active=2459 piece=▁come
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=785 size=480 all=18056 active=2854 piece=▁play
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=727 size=500 all=18374 active=3172 piece=are
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=726 min_freq=146
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=675 size=520 all=18732 active=1281 piece=▁bathrooms
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=637 size=540 all=19264 active=1813 piece=▁Se
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=599 size=560 all=19925 active=2474 piece=▁oven
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=574 size=580 all=20087 active=2636 piece=▁swim
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=537 size=600 all=20412 active=2961 piece=lect
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=536 min_freq=128
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=520 size=620 all=20777 active=1374 piece=very
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=488 size=640 all=21142 active=1739 piece=lic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=470 size=660 all=21454 active=2051 piece=entral
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=444 size=680 all=21730 active=2327 piece=iking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=427 size=700 all=22088 active=2685 piece=▁over
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=427 min_freq=105
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=412 size=720 all=22463 active=1475 piece=▁dishes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=394 size=740 all=22893 active=1905 piece=▁decorated
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=374 size=760 all=23182 active=2194 piece=▁hiking
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=356 size=780 all=23632 active=2644 piece=any
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=343 size=800 all=24025 active=3037 piece=ountry
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=342 min_freq=85
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=329 size=820 all=24239 active=1412 piece=ice
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=319 size=840 all=24560 active=1733 piece=▁open
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=307 size=860 all=24783 active=1956 piece=▁pre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=290 size=880 all=25091 active=2264 piece=▁Suite
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=276 size=900 all=25299 active=2472 piece=▁fish
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=276 min_freq=76
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=268 size=920 all=25493 active=1458 piece=▁holiday
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=940 all=25675 active=1640 piece=▁conven
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=253 size=960 all=26141 active=2106 piece=���Casa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=244 size=980 all=26324 active=2289 piece=▁ro
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=235 size=1000 all=26625 active=2590 piece=▁fo
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=234 min_freq=67
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=227 size=1020 all=27016 active=1715 piece=▁ab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=221 size=1040 all=27185 active=1884 piece=▁small
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=213 size=1060 all=27337 active=2036 piece=▁village
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=207 size=1080 all=27632 active=2331 piece=onal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=199 size=1100 all=27932 active=2631 piece=und
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=199 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=196 size=1120 all=28333 active=1734 piece=▁BBQ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=191 size=1140 all=28500 active=1901 piece=orts
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=185 size=1160 all=28681 active=2082 piece=ourse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=180 size=1180 all=28910 active=2311 piece=▁offering
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=173 size=1200 all=29035 active=2436 piece=▁serving
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=172 min_freq=52
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=168 size=1220 all=29263 active=1680 piece=market
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=164 size=1240 all=29541 active=1958 piece=ions
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=157 size=1260 all=29825 active=2242 piece=tras
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=1280 all=29960 active=2377 piece=▁Qu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=1300 all=30291 active=2708 piece=teri
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=150 min_freq=47
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=1320 all=30457 active=1659 piece=▁Italian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=1340 all=30572 active=1774 piece=▁riding
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=139 size=1360 all=30829 active=2031 piece=CD
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=1380 all=31054 active=2256 piece=mentary
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=1400 all=31408 active=2610 piece=▁safe
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=133 min_freq=43
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=1420 all=31615 active=1778 piece=house
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=1440 all=31807 active=1970 piece=▁Term
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=1460 all=32047 active=2210 piece=▁cafés
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=1480 all=32248 active=2411 piece=ole
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=1500 all=32476 active=2639 piece=▁TVs
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=120 min_freq=39
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=1520 all=32624 active=1772 piece=▁dryer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=1540 all=32766 active=1914 piece=aw
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=1560 all=33061 active=2209 piece=ustic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=1580 all=33287 active=2435 piece=ively
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=1600 all=33460 active=2608 piece=▁book
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=107 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=1620 all=33695 active=1903 piece=▁Roy
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=1640 all=33819 active=2027 piece=oft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=1660 all=34103 active=2311 piece=ired
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=1680 all=34364 active=2572 piece=▁Fran
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=1700 all=34546 active=2754 piece=▁cons
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=95 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=1720 all=34756 active=1930 piece=rich
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=1740 all=34982 active=2156 piece=▁Art
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=89 size=1760 all=35156 active=2330 piece=▁hel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=87 size=1780 all=35274 active=2448 piece=let
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=1800 all=35474 active=2648 piece=▁charming
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=86 min_freq=31
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=1820 all=35723 active=2023 piece=▁per
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=1840 all=35879 active=2179 piece=▁past
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=1860 all=36136 active=2436 piece=itage
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=1880 all=36277 active=2577 piece=▁space
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=79 size=1900 all=36444 active=2744 piece=▁Surrounded
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=78 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=1920 all=36688 active=2067 piece=cia
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=1940 all=36896 active=2275 piece=▁Wal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=1960 all=37058 active=2437 piece=▁great
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=1980 all=37177 active=2556 piece=ictures
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=72 size=2000 all=37318 active=2697 piece=less
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=72 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=2020 all=37506 active=2047 piece=▁Eng
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=2040 all=37711 active=2252 piece=ars
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=2060 all=37890 active=2431 piece=▁Sam
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=2080 all=38094 active=2635 piece=▁disc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=2100 all=38183 active=2724 piece=▁Within
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=67 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=2120 all=38327 active=2054 piece=auty
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=64 size=2140 all=38456 active=2183 piece=skaya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=2160 all=38630 active=2357 piece=▁rec
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=2180 all=38782 active=2509 piece=▁conc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=2200 all=38931 active=2658 piece=▁Zoo
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=61 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=2220 all=39033 active=2049 piece=▁Gar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=2240 all=39094 active=2110 piece=ui
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=2260 all=39298 active=2314 piece=▁Convention
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=2280 all=39424 active=2440 piece=▁courtyard
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=2300 all=39619 active=2635 piece=▁busy
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=2320 all=39740 active=2102 piece=▁Basil
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=2340 all=39819 active=2181 piece=▁Nap
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=2360 all=39934 active=2296 piece=gen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=2380 all=40105 active=2467 piece=▁more
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=2400 all=40232 active=2594 piece=▁Red
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=21
# trainer_interface.cc(687) LOG(INFO) Saving model: m_eng.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m_eng.vocab

# %%
def bpe_tokenizer_en(x):
  return spm.SentencePieceProcessor(model_file = 'm_eng.model').encode(x, out_type = str)

# %%
def bpe_tokenizer_ru(x):
  return spm.SentencePieceProcessor(model_file = 'm_ru.model').encode(x, out_type = str)

# %%
SRC = Field(tokenize=bpe_tokenizer_en,
            init_token = '<sos>',
            eos_token = '<eos>',
            fix_length = 100,
            lower = True)

TRG = Field(tokenize=bpe_tokenizer_ru,
            init_token = '<sos>',
            eos_token = '<eos>',
            fix_length = 100,
            lower = True)

dataset = torchtext.data.TabularDataset(
    path=path_do_data,
    format='tsv',
    fields=[('trg', TRG), ('src', SRC)]
)

# %%
train_data, valid_data, test_data = dataset.split(split_ratio=[0.8, 0.15, 0.05])

# %%
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 40000
# Number of validation examples: 2500
# Number of testing examples: 7500

# %%
SRC.build_vocab(train_data, min_freq = 3)
TRG.build_vocab(train_data, min_freq = 3)

# %%
print(f"Number of unique tokens in source (RU) vocabulary: {len(SRC.vocab)}")
print(f"Number of unique tokens in target (EN) vocabulary: {len(TRG.vocab)}")
# Out:
# Number of unique tokens in source (RU) vocabulary: 8820
# Number of unique tokens in target (EN) vocabulary: 389

# %%
def _len_sort_key(x):
    return len(x.src)

BATCH_SIZE = 128

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size = BATCH_SIZE,
    device = device,
    sort_key=_len_sort_key
)

# %%
import my_network
Encoder = my_network.Encoder
Decoder = my_network.Decoder
Seq2Seq = my_network.Seq2Seq

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

# dont forget to put the model to the right device
model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param, -0.08, 0.08)

model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(8820, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(389, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (out): Linear(in_features=512, out_features=389, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 def count_parameters(model):
#       2     return sum(p.numel() for p in model.parameters() if p.requires_grad)
# ----> 4 print(f'The model has {count_parameters(model):,} trainable parameters')
#
# NameError: name 'model' is not defined

# %%
PAD_IDX = TRG.vocab.stoi['']
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %%
train_history = []
valid_history = []

N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):

    start_time = time.time()

    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut3-model.pt')

    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 10 | Time: 1m 50s
# 	Train Loss: 1.340 | Train PPL:   3.820
# 	 Val. Loss: 3.784 |  Val. PPL:  43.996

# %%
import utils
import imp
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten
# Out:
# /tmp/ipykernel_3499/3680124227.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
batch = next(iter(test_iterator))

# %%
import tqdm

original_text = []
generated_text = []
model.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)

        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])

# original_text = flatten(original_text)
# generated_text = flatten(generated_text)
# Out:
# 0it [00:00, ?it/s]
# 59it [00:07,  7.75it/s]

# %%
seq2seq_bpe_bleu = corpus_bleu([[text] for text in original_text], generated_text) * 100
print(seq2seq_bpe_bleu)
# Out:
# 19.542397904037006

# %% [markdown]
# # Transformer

# %%
from transformer import Seq2SeqTransformer

# %%
torch.manual_seed(0)
PAD_IDX = TRG.vocab.stoi['']

SRC_VOCAB_SIZE = len(SRC.vocab)
TGT_VOCAB_SIZE = len(TRG.vocab)
EMB_SIZE = 512
NHEAD = 8
FFN_HID_DIM = 512
BATCH_SIZE = 128
NUM_ENCODER_LAYERS = 3
NUM_DECODER_LAYERS = 3

transformer = Seq2SeqTransformer(NUM_ENCODER_LAYERS, 
                                 NUM_DECODER_LAYERS, 
                                 EMB_SIZE, 
                                 NHEAD, 
                                 SRC_VOCAB_SIZE, 
                                 TGT_VOCAB_SIZE, 
                                 FFN_HID_DIM)
# Out:
# /home/stanislav/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
for param in transformer.parameters():
    if param.dim() > 1:
        nn.init.xavier_uniform_(param)

# %%
transformer = transformer.to(device)
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=PAD_IDX)
optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

# %%
def generate_square_subsequent_mask(sz, device_):
    mask = (torch.triu(torch.ones((sz, sz), device=device_)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt, device_):
    src_seq_len = src.shape[0]
    tgt_seq_len = tgt.shape[0]
    
    src_mask = torch.zeros((src_seq_len, src_seq_len),device=device_).type(torch.bool)
    tgt_mask = generate_square_subsequent_mask(tgt_seq_len, device_)

    src_padding_mask = (src == PAD_IDX).transpose(0, 1)
    tgt_padding_mask = (tgt == PAD_IDX).transpose(0, 1)
    return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
def train_epoch(model, 
                optimizer, 
                iterator, 
                DEVICE, 
                train_history=None, 
                valid_history=None):
    model.train()
    losses = 0
    history = []
    
    for i, batch in enumerate(iterator):
        src = batch.src.to(DEVICE)
        tgt = batch.trg.to(DEVICE)

        tgt_input = tgt[:-1, :]

        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input, DEVICE)

        logits = model(src, 
                       tgt_input, 
                       src_mask, 
                       tgt_mask,
                       src_padding_mask, 
                       tgt_padding_mask, 
                       src_padding_mask)

        optimizer.zero_grad()

        tgt_out = tgt[1:, :]
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
        loss.backward()

        optimizer.step()
        losses += loss.item()
        
        # plot
        history.append(loss.cpu().data.numpy())
        if (i+1)%10==0:
            fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

            clear_output(True)
            ax[0].plot(history, label='train loss')
            ax[0].set_xlabel('Batch')
            ax[0].set_title('Train loss')
            if train_history is not None:
                ax[1].plot(train_history, label='general train history')
                ax[1].set_xlabel('Epoch')
            if valid_history is not None:
                ax[1].plot(valid_history, label='general valid history')
            plt.legend()
            
            plt.show()
        

    return losses / len(iterator)


def evaluate(model, 
             iterator, 
             DEVICE):
    model.eval()
    losses = 0

    for i, batch in enumerate(iterator):
        src = batch.src.to(DEVICE)
        tgt = batch.trg.to(DEVICE)

        tgt_input = tgt[:-1, :]

        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input, DEVICE)

        logits = model(src, tgt_input, src_mask, tgt_mask,src_padding_mask, tgt_padding_mask, src_padding_mask)
        
        tgt_out = tgt[1:, :]
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))
        losses += loss.item()

    return losses / len(iterator)

# %%
print(f'The model has {count_parameters(transformer):,} trainable parameters')
# Out:
# The model has 24,252,474 trainable parameters

# %%
train_history = []
valid_history = []

N_EPOCHS = 10

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):
    start_time = time.time()
    
    train_loss = train_epoch(transformer, optimizer, train_iterator, device, train_history, valid_history)
    val_loss = evaluate(transformer, valid_iterator, device)

    end_time = time.time()

    train_history.append(train_loss)
    valid_history.append(val_loss)

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 10 | Time: 1m 30s
# 	Train Loss: 0.495 | Train PPL:   1.640
# 	 Val. Loss: 1.804 |  Val. PPL:   6.072

# %%
transformer.eval()
original_text = []
generated_text = []

with torch.no_grad():

  for i, batch in tqdm.tqdm(enumerate(test_iterator)):
      src = batch.src.to(device)
      tgt = batch.trg.to(device)

      tgt_input = tgt[:-1, :]

      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input, device)

      logits = transformer(src, tgt_input, src_mask, tgt_mask,src_padding_mask, tgt_padding_mask, src_padding_mask)
      
      tgt_out = tgt[1:, :]
      logits = logits.argmax(dim=-1)
      generated_text.extend([get_text(x, TRG.vocab) for x in logits.cpu().numpy().T])
      original_text.extend([get_text(x, TRG.vocab) for x in tgt.cpu().numpy().T])
# Out:
# 59it [00:03, 18.59it/s]

# %%
transformer_bleu = corpus_bleu([[text] for text in original_text], generated_text) * 100
print(transformer_bleu)
# Out:
# 28.15490046928225

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this homework I have made 3 improvements to the original translation model, let's depict the resulting BLEU metrics.

# %%
import matplotlib.pyplot as plt

# I reboot ipynb so hardcode previous results
seq2seq_bleu = 
seq2seq_attention_bleu = 16.099354000555635
seq2seq_bpe_bleu = 19.542397904037006
transformer_bleu = 28.15490046928225

variables = ['Baseline', 'Attention', 'BPE', 'Transformer']
values = [seq2seq_bleu, seq2seq_attention_bleu, seq2seq_bpe_bleu, transformer_bleu]

plt.figure(figsize=(6, 6))
plt.title('BLEU values for different models')
plt.xlabel('BLEU')
plt.ylabel('model')

plt.bar(variables, values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2 transformer_bleu = 0
#       4 variables = ['Baseline', 'Attention', 'BPE', 'Transformer']
# ----> 5 values = [seq2seq_bleu, seq2seq_attention_bleu, seq2seq_bpe_bleu, transformer_bleu]
#       7 plt.figure(figsize=(6, 6))
#       8 plt.title('BLEU values for different models')
#
# NameError: name 'seq2seq_bleu' is not defined

# %% [markdown]
# It can be seen that the transformer is the most powerful model.
